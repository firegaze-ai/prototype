# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My\ Drive/Github
# Out:
# /content/gdrive/My Drive/Github

# %%
# !git clone https://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@github.com/orphefs/FireFlyer.git
# Out:
# Cloning into 'FireFlyer'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
# %cd FireFlyer
# Out:
# /content/gdrive/MyDrive/Github/FireFlyer

# %%
# %ls
# Out:
# copy_annotations.py  main.py
